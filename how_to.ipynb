# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import random
pd.set_option('display.max_rows', None)

# %%
#The Basic dataset
df = pd.read_csv('ct_total_be_du_pct_dist.csv', sep='\t')

# %%
#duits duitse grens
#dfgdu=df[["huwplace","all_bg","du_pct","dist_du"]]
dfgdu=df[(df["be_pct"] > 0.8) & (df["be_pct"] < 1.20)]
#dfg=df[(df["be_pct"] < 5.0)]
dfgdu.head(100)
# Out:
#                 huwplace       lat      lng  all_bg  bedu_bg  bedu_pct  \
# 60            Etten-Leur  51.57711  4.64253   11597      134      1.16
# 66               Geldrop  51.42167  5.55972    5688      158      2.78
# 81                 Heeze  51.38280  5.57145    3675       53      1.44
# 82               Helmond  51.48167  5.66111   22104      737      3.33
# 88                Hoeven  51.57917  4.58333    4685       44      0.94
# 113           Moergestel  51.54417  5.17778    2594       29      1.12
# 116      Nieuw-Vossemeer  51.59000  4.21806    2334       23      0.99
# 125           Oisterwijk  51.57917  5.18889    5772       89      1.54
# 127           Oosterhout  51.64500  4.85972   18380      261      1.42
# 131  Oud en Nieuw Gastel  51.58420  4.46530    7477       85      1.14
# 132           Oudenbosch  51.58833  4.53472    6019       78      1.30
# 156          Steenbergen  51.58417  4.31944   12708      141      1.11
# ...
